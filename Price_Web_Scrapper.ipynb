# %% [markdown]
# #Web Scrapper

# %%
class ENV:
    Local = 1
    Colab = 2
    def __init__(self):
      pass

DF_COLS = (['Date', 'Source','Destination','Airline',
            'Price'])


current_env = ENV.Colab # ENV.Local

if current_env == ENV.Colab :
  # !apt update
  # !apt install chromium-chromedriver
  # !pip install selenium

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

def driversetup():
    if current_env == ENV.Colab:
        options = webdriver.ChromeOptions()
        #run Selenium in headless mode
        options.add_argument('--headless')
        options.add_argument('--no-sandbox')
        #overcome limited resource problems
        options.add_argument('--disable-dev-shm-usage')
        options.add_argument("lang=en")
        #open Browser in maximized mode
        options.add_argument("start-maximized")
        #disable infobars
        options.add_argument("disable-infobars")
        #disable extension
        options.add_argument("--disable-extensions")
        options.add_argument("--incognito")
        options.add_argument("--disable-blink-features=AutomationControlled")

        driver = webdriver.Chrome(options=options)

        driver.execute_script("Object.defineProperty(navigator, 'webdriver', {get: () => undefined});")
    elif current_env == ENV.Local:
      chromedriver_path = r"C:\Users\Rahil Bhensdadia\Downloads\Optimization project\Web Scraper\chromedriver-win64\chromedriver.exe"
      chrome_options = webdriver.ChromeOptions() # maybe not needed
      chrome_services = webdriver.ChromeService(executable_path=chromedriver_path)
      driver = webdriver.Chrome(chrome_options,service=chrome_services)

    return driver

# %%
from time import sleep, strftime,time
from random import randint
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import smtplib
from email.mime.multipart import MIMEMultipart
from selenium.webdriver.common.by import By
import datetime
from openpyxl import Workbook

# %%
def page_scrape(driver,city_from, city_to, date_start):
    """This function takes care of the scraping part"""

    kayak_url = ('https://www.kayak.co.in/flights/' + city_from + '-' + city_to +
             '/' + date_start + '?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP')
    print(kayak_url)
    driver.get(kayak_url)
    sleep(30)

    # site_html = BeautifulSoup(driver.page_source,features="html.parser").prettify()
    # file_path = r"C:\Users\Rahil Bhensdadia\Downloads\Optimization\Optimization project\Scheduling_IPL\Web Scraper\site_html.txt"
    # with open(file_path, "w", encoding='utf-8') as file:
    #     file.write(site_html)

    # getting the prices
    cnm_prices = 'f8F1-price-text'
    prices = driver.find_elements(By.CLASS_NAME,cnm_prices, )
    prices = prices[:3]
    prices_list = [price.text.replace('₹','').replace(',','') for price in prices if price.text != '']
    prices_list = list(map(int, prices_list))
    print("Prices :",len(prices_list))

    careers = driver.find_elements(By.CLASS_NAME,"J0g6-operator-text")
    a_carrier = [career.text for career in careers]


    flights_df = pd.DataFrame({'Date':date_start,
                               'Source': city_from,
                               'Destination':city_to,
                               'Airline': a_carrier,
                               'Price': prices_list} )[DF_COLS]

    flights_df['data timestamp'] = strftime("%Y%m%d-%H%M") # so we can know when it was scraped

    return flights_df

# %%
def start_kayak(driver,venues,match_dates):
    print('Finding cheapest results.....')
    df_flights_cheap = pd.DataFrame(columns=DF_COLS)

    # looping for all des src combi for 54 days

    for si in range(4,len(venues)):
        workbook = Workbook()
        workbook.save('FlightData_{}.xlsx'.format(venues[si]))
        for des_i in range(si+1,len(venues)):
            df_flights_cheap_bucket = pd.DataFrame(columns=DF_COLS)
            for date_i in range(len(match_dates)):
                start = time()
                src = venues[si]
                des = venues[des_i]
                flight_date = match_dates[date_i].strftime("%Y-%m-%d")
                flt_data = page_scrape(driver,src, des, flight_date)
                df_flights_cheap_bucket = pd.concat([df_flights_cheap_bucket, flt_data], axis=0)
                end = time()
                print(end-start,"Seconds elaspes for last record")

            with pd.ExcelWriter('FlightData_{}.xlsx'.format(venues[si]), mode='a', if_sheet_exists='overlay') as writer:
                df_flights_cheap_bucket.to_excel(writer, sheet_name=f"{venues[des_i]}", index=False)
            df_flights_cheap = pd.concat([df_flights_cheap,df_flights_cheap_bucket], axis=0)

    df_flights_cheap.to_excel('FlightData_{}.xlsx'.format(strftime("%Y%m%d-%H%M")), index=False)
    print('saved df.....')

# %%
'''
"Chennai" : "MAA",
"Kolkata":"CCU",
"Mohali Chandigard":"IXC",
"Banglore":"BLR",
"Dharamsala":"DHM",
"Jaipur":"JAI"
'''

driver = driversetup()
venues = ["DEL","BOM","HYD","MAA","CCU","IXC","BLR","DHM","JAI"]

base_date = datetime.datetime(year=2024,month = 5, day=24)
match_dates = [(base_date+datetime.timedelta(days=i)).date() for i in range(54)] #54
start_kayak(driver,venues, match_dates)

driver.save_screenshot('pythonscraping.png')

driver.close()
# Out:
# Finding cheapest results.....
# https://www.kayak.co.in/flights/CCU-IXC/2024-05-24?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 31.0479953289032 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-05-25?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.717918872833252 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-05-26?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.963717222213745 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-05-27?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.734219789505005 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-05-28?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.822548627853394 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-05-29?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.681247234344482 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-05-30?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.62231707572937 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-05-31?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.62997007369995 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-01?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.66358470916748 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-02?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.487938404083252 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-03?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.472917318344116 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-04?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.580364227294922 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-05?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.524909019470215 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-06?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.64146590232849 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-07?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.64762282371521 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-08?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.665446043014526 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-09?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.703122854232788 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-10?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.695955991744995 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-11?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.67853093147278 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-12?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.630951404571533 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-13?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.64640784263611 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-14?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.678441286087036 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-15?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.67149019241333 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-16?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.639092683792114 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-17?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.607134580612183 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-18?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.68260645866394 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-19?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.67997646331787 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-20?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.522085428237915 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-21?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.547890663146973 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-22?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.56791925430298 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-23?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.51831579208374 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-24?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.56006169319153 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-25?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.51199769973755 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-26?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.54464817047119 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-27?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.51950478553772 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-28?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.499117612838745 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-29?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.501537322998047 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-06-30?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.504921197891235 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-01?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.480858325958252 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-02?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.558696031570435 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-03?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.613130569458008 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-04?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.659950017929077 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-05?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.646055936813354 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-06?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.629563570022583 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-07?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.63357138633728 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-08?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.511075496673584 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-09?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.524873971939087 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-10?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.467609405517578 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-11?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.546541690826416 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-12?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.51761555671692 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-13?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.48765730857849 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-14?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.481748342514038 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-15?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.48790192604065 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-IXC/2024-07-16?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.53651189804077 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-05-24?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.681705713272095 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-05-25?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.608034372329712 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-05-26?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.645533323287964 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-05-27?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.678396701812744 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-05-28?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.657984972000122 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-05-29?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.662780284881592 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-05-30?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.573479652404785 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-05-31?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.534891366958618 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-01?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.514750003814697 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-02?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.585460424423218 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-03?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.57762861251831 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-04?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.59477710723877 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-05?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.52964735031128 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-06?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.581469774246216 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-07?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.66158151626587 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-08?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.670845985412598 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-09?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.68822455406189 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-10?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.65668821334839 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-11?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.64836096763611 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-12?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.504104614257812 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-13?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.62238574028015 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-14?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.547260522842407 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-15?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.58006262779236 Seconds elaspes for last record
# https://www.kayak.co.in/flights/CCU-BLR/2024-06-16?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30
Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-05-26?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.625755548477173 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-05-27?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.62088131904602 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-05-28?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.630118131637573 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-05-29?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.51582098007202 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-05-30?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.530598640441895 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-05-31?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.511584997177124 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-01?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.449883222579956 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-02?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.491875171661377 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-03?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.452186584472656 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-04?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.531013011932373 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-05?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.504644870758057 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-06?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.50943374633789 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-07?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.472917079925537 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-08?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.52156901359558 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-09?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.62674593925476 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-10?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.659010410308838 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-11?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP
# Prices : 0
# 30.617128610610962 Seconds elaspes for last record
# https://www.kayak.co.in/flights/IXC-BLR/2024-06-12?sort=price_a&fs=airlines=-flylocal,SG,S5,MULT,X1,QP

# %% [markdown]
# #Hotel Prices

# %%
DF_HOTEL_COLS = (['Date', 'Venue','Hotel Name',
            'Price'])

# %%
def get_prices(driver,venue, checkin_date, checkout_date):
    """This function takes care of the scraping part"""

    kayak_url = ('https://www.kayak.co.in/hotels/' + venue +
             '/' + checkin_date + '/' + checkout_date + '/2adults;map?sort=price_a&fs=stars=5;hotelchain=br-146,br-411')
    print(kayak_url)
    driver.get(kayak_url)
    sleep(30)

    # site_html = BeautifulSoup(driver.page_source,features="html.parser").prettify()
    # file_path = r"C:\Users\Rahil Bhensdadia\Downloads\Optimization\Optimization project\Scheduling_IPL\Web Scraper\site_html.txt"
    # with open(file_path, "w", encoding='utf-8') as file:
    #     file.write(site_html)

    # getting the prices
    cnm_prices = 'D8J--price'
    prices = driver.find_elements(By.CLASS_NAME,cnm_prices)[:10]

    prices_list = [price.text.replace('₹','').replace(',','') for price in prices if price.text != '']
    prices_list = list(map(int, prices_list))
    # print("Prices :",len(prices_list))
    # flights_times = driver.find_elements(By.CLASS_NAME,"VY2U")
    # flights_time = [stop[0].text for stop in flights_times] ############################

    hotel_elements = driver.find_elements(By.CLASS_NAME,"IirT-header")[:10]
    hotel_names = [career.text for career in hotel_elements]

    #print(checkin_date,venue,len(hotel_names),len(prices_list))
    hotels_df = pd.DataFrame({'Date':checkin_date,
                               'Venue': venue,
                               'Hotel Name': hotel_names,
                               'Price': prices_list} )[DF_HOTEL_COLS]

    hotels_df['data timestamp'] = strftime("%Y%m%d-%H%M") # so we can know when it was scraped

    return hotels_df

# %%
def start_hotel_scraping(driver,venues,match_dates):
    print('Finding cheapest results.....')
    df_hotel = pd.DataFrame(columns=DF_COLS)

    # looping for all venues combi for 54 days

    for si in range(len(venues)):
        df_hotel_bucket = pd.DataFrame(columns=DF_COLS)
        workbook = Workbook()
        workbook.save('.\datastore\HotelData_{}.xlsx'.format(venues[si]))
        for date_i in range(len(match_dates)-1):
            start = time()
            venue = venues[si]
            checkin_date = match_dates[date_i].strftime("%Y-%m-%d")
            checkout_date = match_dates[date_i+1].strftime("%Y-%m-%d")
            # print(src,des,flight_date)
            hotel_data = get_prices(driver,venue, checkin_date,checkout_date)
            df_hotel_bucket = pd.concat([df_hotel_bucket, hotel_data], axis=0)
            end = time()
            print(end-start,"Seconds elaspes for last record")

        with pd.ExcelWriter('.\datastore\HotelData_{}.xlsx'.format(venues[si]), mode='a', if_sheet_exists='overlay') as writer:
                df_hotel_bucket.to_excel(writer, sheet_name=f"{venues[si]}", index=False)

        df_hotel_bucket.to_excel('.\datastore\HotelData_{}.xlsx'.format(venues[si]), index=False)
        df_hotel = pd.concat([df_hotel,df_hotel_bucket], axis=0)

    df_hotel.to_excel('.\datastore\HotelData_{}.xlsx'.format(strftime("%Y%m%d-%H%M")), index=False)
    print('saved df.....')

# %%
driver = driversetup()
venues = ["DEL","BOM","HYD","MAA","CCU","IXC","BLR","DHM","JAI"]

venues_directore = {
                    "DEL":"New-Delhi,National-Capital-Territory-of-India,India-p14282",
                    "BOM":"Mumbai,Maharashtra,India-p15926",
                    "HYD":"Hyderabad,Telangana,India-p15297",
                    "MAA":"Chennai,Tamil-Nadu,India-p14679",
                    "CCU":"Kolkata,West-Bengal,India-p15904",
                    "IXC":"Chandigarh,India-p15870",
                    "BLR":"Bengaluru,Karnataka,India-p16183",
                    "DHM" : "Dharamshala,Himachal-Pradesh,India-p15662",
                    "JAI" : "Jaipur,Rajasthan,India-p15247"
                    }
base_date = datetime.datetime(year=2024,month = 5, day=24)
MATCH_DAYS = 54
match_dates = [(base_date+datetime.timedelta(days=i)).date() for i in range(MATCH_DAYS+1)]
start_hotel_scraping(driver,list(venues_directore.values()), match_dates)

driver.close()
# Out:
# Finding cheapest results.....
# https://www.kayak.co.in/hotels/New-Delhi,National-Capital-Territory-of-India,India-p14282/2024-05-24/2024-05-25/2adults;map?sort=price_a&fs=stars=5;hotelchain=br-146,br-411
# 31.405624628067017 Seconds elaspes for last record
# https://www.kayak.co.in/hotels/New-Delhi,National-Capital-Territory-of-India,India-p14282/2024-05-25/2024-05-26/2adults;map?sort=price_a&fs=stars=5;hotelchain=br-146,br-411
# 30.81840968132019 Seconds elaspes for last record
# https://www.kayak.co.in/hotels/New-Delhi,National-Capital-Territory-of-India,India-p14282/2024-05-26/2024-05-27/2adults;map?sort=price_a&fs=stars=5;hotelchain=br-146,br-411
# 30.978936672210693 Seconds elaspes for last record
# https://www.kayak.co.in/hotels/New-Delhi,National-Capital-Territory-of-India,India-p14282/2024-05-27/2024-05-28/2adults;map?sort=price_a&fs=stars=5;hotelchain=br-146,br-411
# 30.745112657546997 Seconds elaspes for last record
# https://www.kayak.co.in/hotels/New-Delhi,National-Capital-Territory-of-India,India-p14282/2024-05-28/2024-05-29/2adults;map?sort=price_a&fs=stars=5;hotelchain=br-146,br-411
# 30.837909936904907 Seconds elaspes for last record
# https://www.kayak.co.in/hotels/New-Delhi,National-Capital-Territory-of-India,India-p14282/2024-05-29/2024-05-30/2adults;map?sort=price_a&fs=stars=5;hotelchain=br-146,br-411
